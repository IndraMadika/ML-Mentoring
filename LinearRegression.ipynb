# %% [markdown]
# <a href="https://colab.research.google.com/github/IndraMadika/ML-Mentoring/blob/main/LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.linear_model import LinearRegression

# Membentuk data training
X_train = [[1], [2], [3], [4]]
y_train = [2, 4, 6, 8]

# Inisialisasi model regresi linier
model = LinearRegression()

# Melatih model dengan data training
model.fit(X_train, y_train)

# Data baru untuk prediksi
X_new = [[5], [6]]

# Melakukan prediksi
y_pred = model.predict(X_new)

print("Prediksi:", y_pred)
# Out:
# Prediksi: [10. 12.]

# %%
import matplotlib.pyplot as plt
# Visualisasi Data dan Hasil Prediksi
plt.scatter(X_train, y_train, color='blue', label='Data')
plt.plot(X_new, y_pred, color='red', label='Regression Line')
plt.xlabel('X')
plt.ylabel('y')
plt.title('Linear Regression')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Data training
X_train = np.array([[1, 2], [2, 3], [3, 4], [4, 5]])
y_train = np.array([5, 8, 12, 15])

# Inisialisasi model regresi linear
model = LinearRegression()

# Melatih model dengan data training
model.fit(X_train, y_train)

# Data baru untuk prediksi
X_new = np.array([[5, 6], [6, 7]])

# Melakukan prediksi
y_pred = model.predict(X_new)

# Visualisasi data training dan garis regresi
plt.scatter(X_train[:, 0], y_train, color='blue', label='Data Training')
plt.plot(X_train[:, 0], model.predict(X_train), color='red', label='Linear Regression')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Multiple Linear Regression')
plt.legend()
plt.show()

print("Prediksi:", y_pred)
# Out:
# Prediksi: [18.5 21.9]
